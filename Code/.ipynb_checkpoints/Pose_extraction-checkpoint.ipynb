# %%
import numpy as np
import pandas as pd
import os
from pathlib import Path
import subprocess

# %%
# %cd c:/openpose/
# Out:
# c:\openpose

# %%
# !echo %cd%
# Out:
# c:\openpose

# %% [markdown]
# ## Manually specify input folder and file to process

# %%
input_p = Path("C:/Users/llonini/Box/CISPD_Videos_proc/NU/1052Fluctuator/Edited/")
outposefile = Path('output/1052/') 
outvideofile = Path('outputvideo/1052/')
files = os.listdir(input_p)
f = files[-1]
print(input_p/f)
print(f + '.avi')
# Out:
# C:\Users\llonini\Box\CISPD_Videos_proc\NU\1052Fluctuator\Edited\Cycle2_Wlkg.mp4
# Cycle2_Wlkg.mp4.avi

# %%
os.listdir(input_p)
# Out:
# ['Cycle2_FtnL.mp4',
#  'Cycle2_FtnR.mp4',
#  'Cycle2_RamL.mp4',
#  'Cycle2_RamR.mp4',
#  'Cycle2_Sitng.mp4',
#  'Cycle2_SitStand.mp4',
#  'Cycle2_Stndg.mp4']

# %%
x1 = (input_p/f).as_posix()
x2 = outposefile.as_posix()
x3 = (outvideofile/(f[:-3]+'avi')).as_posix()
print(x1)
print(x2)
print(x3)
# Out:
# C:/Users/llonini/Box/CISPD_Videos_proc/NU/1052Fluctuator/Edited/Cycle2_Wlkg.mp4
# output/1052
# outputvideo/1052/Cycle2_Wlkg.avi

# %% [markdown]
# Run openpose

# %%
# !savepose.bat {x1} {x2} {x3}
# Out:
# (base) c:\openpose>ECHO OFF
# input file C:/Users/llonini/Box/CISPD_Videos_proc/NU/1052Fluctuator/Edited/Cycle2_Wlkg.mp4
# output pose folder output/1052
# output videopose folder outputvideo/1052/Cycle2_Wlkg.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 39.515168 seconds.

# %% [markdown]
# ## Process batch

# %%
Path('output/'+s)
# Out:
# WindowsPath('output/1043')

# %%
outvideofile
# Out:
# WindowsPath('outputvideo/1043')

# %%
os.mkdir(outposefile)

# %%
input_p = Path("C:/Users/llonini/Box/CISPD_Videos_proc/Edited")
subjs = os.listdir(input_p)
for s in subjs:
#     print(input_p/s, os.listdir(input_p/s)) #folder subject
    subjfiles = os.listdir(input_p/s) #subject video files
    for f in subjfiles:

        print(input_p/s/f) #current file being processed        
        outposefile = Path('output/'+s) 
        outvideofile = Path('outputvideo/'+s)        
        #create subj folder if does not exist
        if not os.path.exists(outposefile):
            os.mkdir(outposefile)
        if not os.path.exists(outvideofile):
            os.mkdir(outvideofile)

        x1 = input_p/s/f
        x2 = outposefile.as_posix()
        x3 = (outvideofile/(f[:-3]+'avi')).as_posix()
        print(x1)
        print(x2)
        print(x3)
        # !savepose.bat {x1} {x2} {x3}
# Out:
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1004\FtnL_1.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1004\FtnL_1.mp4
# output/1004
# outputvideo/1004/FtnL_1.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1004\FtnL_1.mp4
# output pose folder output/1004
# output videopose folder outputvideo/1004/FtnL_1.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 219.482281 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1004\FtnL_3.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1004\FtnL_3.mp4
# output/1004
# outputvideo/1004/FtnL_3.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1004\FtnL_3.mp4
# output pose folder output/1004
# output videopose folder outputvideo/1004/FtnL_3.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 228.598356 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1004\FtnR_1.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1004\FtnR_1.mp4
# output/1004
# outputvideo/1004/FtnR_1.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1004\FtnR_1.mp4
# output pose folder output/1004
# output videopose folder outputvideo/1004/FtnR_1.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 202.968181 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1004\FtnR_3.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1004\FtnR_3.mp4
# output/1004
# outputvideo/1004/FtnR_3.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1004\FtnR_3.mp4
# output pose folder output/1004
# output videopose folder outputvideo/1004/FtnR_3.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 259.828308 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1004\RamL_1.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1004\RamL_1.mp4
# output/1004
# outputvideo/1004/RamL_1.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1004\RamL_1.mp4
# output pose folder output/1004
# output videopose folder outputvideo/1004/RamL_1.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 222.271496 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1004\RamL_3.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1004\RamL_3.mp4
# output/1004
# outputvideo/1004/RamL_3.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1004\RamL_3.mp4
# output pose folder output/1004
# output videopose folder outputvideo/1004/RamL_3.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 222.434120 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1004\RamR_1.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1004\RamR_1.mp4
# output/1004
# outputvideo/1004/RamR_1.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1004\RamR_1.mp4
# output pose folder output/1004
# output videopose folder outputvideo/1004/RamR_1.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 209.105468 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1004\SitStand_1.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1004\SitStand_1.mp4
# output/1004
# outputvideo/1004/SitStand_1.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1004\SitStand_1.mp4
# output pose folder output/1004
# output videopose folder outputvideo/1004/SitStand_1.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 52.591953 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1004\SitStand_3.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1004\SitStand_3.mp4
# output/1004
# outputvideo/1004/SitStand_3.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1004\SitStand_3.mp4
# output pose folder output/1004
# output videopose folder outputvideo/1004/SitStand_3.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 59.815034 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1009\FtnL_1.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1009\FtnL_1.mp4
# output/1009
# outputvideo/1009/FtnL_1.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1009\FtnL_1.mp4
# output pose folder output/1009
# output videopose folder outputvideo/1009/FtnL_1.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 277.969569 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1009\FtnL_3.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1009\FtnL_3.mp4
# output/1009
# outputvideo/1009/FtnL_3.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1009\FtnL_3.mp4
# output pose folder output/1009
# output videopose folder outputvideo/1009/FtnL_3.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 246.478637 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1009\FtnR_1.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1009\FtnR_1.mp4
# output/1009
# outputvideo/1009/FtnR_1.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1009\FtnR_1.mp4
# output pose folder output/1009
# output videopose folder outputvideo/1009/FtnR_1.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 290.639067 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1009\FtnR_3.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1009\FtnR_3.mp4
# output/1009
# outputvideo/1009/FtnR_3.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1009\FtnR_3.mp4
# output pose folder output/1009
# output videopose folder outputvideo/1009/FtnR_3.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 318.804871 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1009\RamL_1.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1009\RamL_1.mp4
# output/1009
# outputvideo/1009/RamL_1.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1009\RamL_1.mp4
# output pose folder output/1009
# output videopose folder outputvideo/1009/RamL_1.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 172.233957 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1009\RamL_3.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1009\RamL_3.mp4
# output/1009
# outputvideo/1009/RamL_3.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1009\RamL_3.mp4
# output pose folder output/1009
# output videopose folder outputvideo/1009/RamL_3.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 142.637001 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1009\RamR_1.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1009\RamR_1.mp4
# output/1009
# outputvideo/1009/RamR_1.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1009\RamR_1.mp4
# output pose folder output/1009
# output videopose folder outputvideo/1009/RamR_1.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 166.190959 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1009\RamR_3.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1009\RamR_3.mp4
# output/1009
# outputvideo/1009/RamR_3.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1009\RamR_3.mp4
# output pose folder output/1009
# output videopose folder outputvideo/1009/RamR_3.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 155.166724 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1009\SitStand_1.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1009\SitStand_1.mp4
# output/1009
# outputvideo/1009/SitStand_1.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1009\SitStand_1.mp4
# output pose folder output/1009
# output videopose folder outputvideo/1009/SitStand_1.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 74.848973 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1009\SitStand_3.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1009\SitStand_3.mp4
# output/1009
# outputvideo/1009/SitStand_3.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1009\SitStand_3.mp4
# output pose folder output/1009
# output videopose folder outputvideo/1009/SitStand_3.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 61.343104 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1039\FtnL_1.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1039\FtnL_1.mp4
# output/1039
# outputvideo/1039/FtnL_1.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1039\FtnL_1.mp4
# output pose folder output/1039
# output videopose folder outputvideo/1039/FtnL_1.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 52.232819 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1039\FtnL_3.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1039\FtnL_3.mp4
# output/1039
# outputvideo/1039/FtnL_3.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1039\FtnL_3.mp4
# output pose folder output/1039
# output videopose folder outputvideo/1039/FtnL_3.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 77.426428 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1039\FtnR_1.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1039\FtnR_1.mp4
# output/1039
# outputvideo/1039/FtnR_1.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1039\FtnR_1.mp4
# output pose folder output/1039
# output videopose folder outputvideo/1039/FtnR_1.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 79.958497 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1039\FtnR_3.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1039\FtnR_3.mp4
# output/1039
# outputvideo/1039/FtnR_3.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1039\FtnR_3.mp4
# output pose folder output/1039
# output videopose folder outputvideo/1039/FtnR_3.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 78.611529 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1039\RamL_1.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1039\RamL_1.mp4
# output/1039
# outputvideo/1039/RamL_1.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1039\RamL_1.mp4
# output pose folder output/1039
# output videopose folder outputvideo/1039/RamL_1.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 75.290907 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1039\RamL_3.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1039\RamL_3.mp4
# output/1039
# outputvideo/1039/RamL_3.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1039\RamL_3.mp4
# output pose folder output/1039
# output videopose folder outputvideo/1039/RamL_3.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 78.255913 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1039\RamR_1.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1039\RamR_1.mp4
# output/1039
# outputvideo/1039/RamR_1.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1039\RamR_1.mp4
# output pose folder output/1039
# output videopose folder outputvideo/1039/RamR_1.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 79.001342 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1039\RamR_3.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1039\RamR_3.mp4
# output/1039
# outputvideo/1039/RamR_3.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1039\RamR_3.mp4
# output pose folder output/1039
# output videopose folder outputvideo/1039/RamR_3.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 84.010775 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1039\SitStand_1.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1039\SitStand_1.mp4
# output/1039
# outputvideo/1039/SitStand_1.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1039\SitStand_1.mp4
# output pose folder output/1039
# output videopose folder outputvideo/1039/SitStand_1.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 47.672741 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1039\SitStand_3.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1039\SitStand_3.mp4
# output/1039
# outputvideo/1039/SitStand_3.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1039\SitStand_3.mp4
# output pose folder output/1039
# output videopose folder outputvideo/1039/SitStand_3.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 53.624552 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1043\FtnL_1.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1043\FtnL_1.mp4
# output/1043
# outputvideo/1043/FtnL_1.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1043\FtnL_1.mp4
# output pose folder output/1043
# output videopose folder outputvideo/1043/FtnL_1.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 69.971191 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1043\FtnL_3.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1043\FtnL_3.mp4
# output/1043
# outputvideo/1043/FtnL_3.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1043\FtnL_3.mp4
# output pose folder output/1043
# output videopose folder outputvideo/1043/FtnL_3.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 105.201663 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1043\FtnR_1.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1043\FtnR_1.mp4
# output/1043
# outputvideo/1043/FtnR_1.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1043\FtnR_1.mp4
# output pose folder output/1043
# output videopose folder outputvideo/1043/FtnR_1.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 75.008715 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1043\FtnR_3.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1043\FtnR_3.mp4
# output/1043
# outputvideo/1043/FtnR_3.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1043\FtnR_3.mp4
# output pose folder output/1043
# output videopose folder outputvideo/1043/FtnR_3.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 98.287480 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1043\RamL_1.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1043\RamL_1.mp4
# output/1043
# outputvideo/1043/RamL_1.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1043\RamL_1.mp4
# output pose folder output/1043
# output videopose folder outputvideo/1043/RamL_1.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 66.432429 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1043\RamL_3.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1043\RamL_3.mp4
# output/1043
# outputvideo/1043/RamL_3.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1043\RamL_3.mp4
# output pose folder output/1043
# output videopose folder outputvideo/1043/RamL_3.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 71.804399 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1043\RamR_1.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1043\RamR_1.mp4
# output/1043
# outputvideo/1043/RamR_1.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1043\RamR_1.mp4
# output pose folder output/1043
# output videopose folder outputvideo/1043/RamR_1.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 80.347337 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1043\RamR_3.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1043\RamR_3.mp4
# output/1043
# outputvideo/1043/RamR_3.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1043\RamR_3.mp4
# output pose folder output/1043
# output videopose folder outputvideo/1043/RamR_3.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 81.674004 seconds.
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1043\SitStand_3.mp4
# C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1043\SitStand_3.mp4
# output/1043
# outputvideo/1043/SitStand_3.avi
#
# (base) c:\openpose>ECHO OFF
# input file C:\Users\llonini\Box\CISPD_Videos_proc\Edited\1043\SitStand_3.mp4
# output pose folder output/1043
# output videopose folder outputvideo/1043/SitStand_3.avi
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 85.687993 seconds.

# %% [markdown]
# You cannot use !cd to navigate the filesystem from Jupyter notebook. The reason is that shell commands in the notebook are executed in a temporary subshell. If you'd like to change the working directory, you can use the %cd magic command
# https://stackoverflow.com/questions/53188176/fail-to-change-directory-shell-command-in-jupyternotebook-or-jupyterlab-sessi

# %%
op_path = Path('C:\openpose')
# %cd C:\openpose #need to use
# Out:
# C:\openpose
